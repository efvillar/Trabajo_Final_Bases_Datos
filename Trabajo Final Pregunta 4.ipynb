# %% [markdown]
# # PREGUNTA 4
# ## Aplique MapReduce para llevar esos datos a una base de datos NoSQL que permita agrupar el número de programadores por lenguaje de programación y las respuestas por pregunta de los 5 conjuntos en paralelo* (Mediante Map Reduce).  (Adjunte la rutina en Python, SQL y/o Javascript que le permitió obtener la base de datos SQL en paralelo, deberá adjuntar evidencia del procesamiento en paralelo y hará parte de la exposición la demostración de la rutina)

# %% [markdown]
# #### Primero se unen los archivos json en uno solo
# Se usa pandas para leer los archivo y para exportarlos de nuevo

# %%
import json
import pandas as pd
import os

# %%
data1 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_0_16000.json')
data2 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_16000_32000.json')
data3 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_32000_48000.json')
data4 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_48000_64000.json')
data5 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_64000_80000.json')
data6 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_80000_96000.json')
data7 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_96000_112000.json')
data8 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_112000_128000.json')
data9 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_128000_144000.json')
data10 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_144000_160000.json')
data11 = pd.read_json(r'.\Base_Datos_Encuestas\BD_Encuesta_160000_160111.json')

# %%
data1.shape
# Out:
# (16000, 24)

# %%
data10.head(5)
# Out:
#    AngularJS     C CPlusPlus  CSS CSharp  HTML5  Id_Age  Id_Country  \
# 0        NaN  None      None  NaN     C#    NaN     NaN          33
# 1        NaN  None      None  NaN   None    NaN     NaN          36
# 2        NaN  None      None  NaN   None    NaN     NaN         165
# 3        NaN  None      None  NaN     C#    NaN     NaN         213
# 4        NaN  None      None  NaN     C#    NaN     NaN         212
#
#    Id_Experience  Id_Gender  ...  ObjectiveC   PHP  Perl  Python  Ruby   SQL  \
# 0            6.0          4  ...        None  None  None    None  None  None
# 1            6.0          2  ...        None  None  None    None  Ruby  None
# 2            6.0          4  ...        None  None  None    None  None  None
# 3            6.0          2  ...        None  None  None    None  None   SQL
# 4            6.0          2  ...        None  None  None    None  None   SQL
#
#   SQL_Server TypeScript  Year jQuery
# 0        NaN       None  2017    NaN
# 1        NaN       None  2017    NaN
# 2        NaN       None  2017    NaN
# 3        NaN       None  2017    NaN
# 4        NaN       None  2017    NaN
#
# [5 rows x 24 columns]

# %%
Total = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10], axis=0)

# %%
Total.shape
# Out:
# (160000, 24)

# %%
Total.tail()
# Out:
#       AngularJS     C CPlusPlus  CSS CSharp HTML5  Id_Age  Id_Country  \
# 15995       NaN  None      None  NaN   None   NaN     NaN       210.0
# 15996       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15997       NaN  None      None  NaN     C#   NaN     NaN       213.0
# 15998       NaN  None      None  NaN     C#   NaN     NaN        56.0
# 15999       NaN  None      None  NaN     C#   NaN     NaN       213.0
#
#        Id_Experience  Id_Gender  ...   ObjectiveC   PHP  Perl Python  Ruby  \
# 15995            4.0        4.0  ...         None  None  None   None  None
# 15996            6.0        4.0  ...         None  None  None   None  None
# 15997            5.0        2.0  ...  Objective-C  None  None   None  None
# 15998            6.0        2.0  ...         None  None  None   None  None
# 15999            5.0        2.0  ...         None  None  None   None  None
#
#         SQL SQL_Server  TypeScript  Year jQuery
# 15995  None        NaN        None  2017    NaN
# 15996  None        NaN        None  2017    NaN
# 15997   SQL        NaN  TypeScript  2017    NaN
# 15998   SQL        NaN  TypeScript  2017    NaN
# 15999   SQL        NaN        None  2017    NaN
#
# [5 rows x 24 columns]

# %%
Total = Total.reset_index()

# %%
Total = Total.drop(['index'], axis=1)

# %%
Total.tail(300)
# Out:
#       AngularJS     C CPlusPlus  CSS CSharp HTML5  Id_Age  Id_Country  \
# 15700       NaN     C       C++  NaN   None   NaN     NaN        93.0
# 15701       NaN  None      None  NaN     C#   NaN     NaN       213.0
# 15702       NaN  None      None  NaN   None   NaN     NaN        78.0
# 15703       NaN  None      None  NaN   None   NaN     NaN        94.0
# 15704       NaN  None      None  NaN   None   NaN     NaN        78.0
# 15705       NaN  None      None  NaN   None   NaN     NaN        93.0
# 15706       NaN     C       C++  NaN     C#   NaN     NaN       130.0
# 15707       NaN  None      None  NaN   None   NaN     NaN       190.0
# 15708       NaN  None      None  NaN     C#   NaN     NaN       191.0
# 15709       NaN  None      None  NaN     C#   NaN     NaN        42.0
# 15710       NaN  None       C++  NaN     C#   NaN     NaN       213.0
# 15711       NaN  None      None  NaN     C#   NaN     NaN       144.0
# 15712       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15713       NaN  None      None  NaN   None   NaN     NaN        93.0
# 15714       NaN  None      None  NaN   None   NaN     NaN       144.0
# 15715       NaN  None      None  NaN     C#   NaN     NaN        60.0
# 15716       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15717       NaN  None       C++  NaN     C#   NaN     NaN       144.0
# 15718       NaN  None       C++  NaN   None   NaN     NaN       213.0
# 15719       NaN  None       C++  NaN     C#   NaN     NaN       137.0
# 15720       NaN     C      None  NaN   None   NaN     NaN       162.0
# 15721       NaN  None      None  NaN     C#   NaN     NaN       145.0
# 15722       NaN  None      None  NaN   None   NaN     NaN        93.0
# 15723       NaN     C       C++  NaN     C#   NaN     NaN       227.0
# 15724       NaN  None      None  NaN   None   NaN     NaN        42.0
# 15725       NaN     C       C++  NaN     C#   NaN     NaN       213.0
# 15726       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15727       NaN     C       C++  NaN     C#   NaN     NaN       209.0
# 15728       NaN  None      None  NaN     C#   NaN     NaN        84.0
# 15729       NaN     C      None  NaN   None   NaN     NaN        78.0
# ...         ...   ...       ...  ...    ...   ...     ...         ...
# 15970       NaN     C       C++  NaN   None   NaN     NaN        78.0
# 15971       NaN  None      None  NaN   None   NaN     NaN       212.0
# 15972       NaN  None      None  NaN     C#   NaN     NaN       213.0
# 15973       NaN  None       C++  NaN   None   NaN     NaN       212.0
# 15974       NaN     C      None  NaN   None   NaN     NaN        49.0
# 15975       NaN  None       C++  NaN     C#   NaN     NaN       213.0
# 15976       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15977       NaN  None      None  NaN   None   NaN     NaN       191.0
# 15978       NaN  None      None  NaN     C#   NaN     NaN       212.0
# 15979       NaN  None       C++  NaN   None   NaN     NaN        42.0
# 15980       NaN  None      None  NaN   None   NaN     NaN        16.0
# 15981       NaN  None       C++  NaN     C#   NaN     NaN       188.0
# 15982       NaN  None      None  NaN   None   NaN     NaN        74.0
# 15983       NaN  None      None  NaN   None   NaN     NaN        59.0
# 15984       NaN     C      None  NaN   None   NaN     NaN       213.0
# 15985       NaN  None      None  NaN   None   NaN     NaN        60.0
# 15986       NaN     C       C++  NaN     C#   NaN     NaN        42.0
# 15987       NaN  None       C++  NaN     C#   NaN     NaN       212.0
# 15988       NaN  None      None  NaN   None   NaN     NaN       130.0
# 15989       NaN  None      None  NaN   None   NaN     NaN        74.0
# 15990       NaN  None      None  NaN   None   NaN     NaN        73.0
# 15991       NaN  None      None  NaN   None   NaN     NaN       212.0
# 15992       NaN  None       C++  NaN   None   NaN     NaN        78.0
# 15993       NaN  None      None  NaN   None   NaN     NaN        66.0
# 15994       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15995       NaN  None      None  NaN   None   NaN     NaN       210.0
# 15996       NaN  None      None  NaN   None   NaN     NaN       213.0
# 15997       NaN  None      None  NaN     C#   NaN     NaN       213.0
# 15998       NaN  None      None  NaN     C#   NaN     NaN        56.0
# 15999       NaN  None      None  NaN     C#   NaN     NaN       213.0
#
#        Id_Experience  Id_Gender  ...   ObjectiveC   PHP  Perl  Python  Ruby  \
# 15700            6.0        2.0  ...         None   PHP  None  Python  None
# 15701            6.0        2.0  ...         None   PHP  None  Python  None
# 15702            6.0        4.0  ...         None  None  None    None  None
# 15703            4.0        4.0  ...         None  None  None    None  None
# 15704            4.0        4.0  ...         None  None  None    None  None
# 15705            5.0        4.0  ...         None  None  None    None  None
# 15706            6.0        2.0  ...  Objective-C   PHP  None    None  None
# 15707            6.0        4.0  ...         None  None  None    None  None
# 15708            4.0        2.0  ...         None  None  None    None  None
# 15709            6.0        2.0  ...         None   PHP  None    None  None
# 15710            6.0        2.0  ...         None  None  None    None  None
# 15711            6.0        2.0  ...  Objective-C   PHP  None  Python  None
# 15712            5.0        4.0  ...         None   PHP  None    None  None
# 15713            4.0        4.0  ...         None  None  None    None  None
# 15714            6.0        2.0  ...         None   PHP  None    None  None
# 15715            4.0        2.0  ...         None   PHP  None  Python  None
# 15716            4.0        4.0  ...         None  None  None    None  None
# 15717            6.0        2.0  ...         None  None  None    None  None
# 15718            5.0        2.0  ...  Objective-C  None  None  Python  Ruby
# 15719            6.0        2.0  ...         None  None  None    None  None
# 15720            6.0        2.0  ...         None  None  Perl    None  None
# 15721            6.0        2.0  ...         None  None  None    None  None
# 15722            5.0        4.0  ...         None  None  None    None  None
# 15723            6.0        2.0  ...  Objective-C   PHP  Perl    None  None
# 15724            6.0        4.0  ...         None  None  None    None  None
# 15725            6.0        2.0  ...         None  None  None  Python  None
# 15726            6.0        4.0  ...         None  None  None    None  None
# 15727            4.0        4.0  ...  Objective-C   PHP  None  Python  Ruby
# 15728            6.0        2.0  ...         None   PHP  None    None  None
# 15729            6.0        2.0  ...         None   PHP  Perl    None  None
# ...              ...        ...  ...          ...   ...   ...     ...   ...
# 15970            6.0        2.0  ...         None   PHP  Perl  Python  Ruby
# 15971            6.0        4.0  ...         None  None  None    None  None
# 15972            6.0        2.0  ...         None   PHP  None    None  None
# 15973            6.0        4.0  ...         None  None  None  Python  None
# 15974            3.0        4.0  ...         None   PHP  None    None  None
# 15975            6.0        2.0  ...  Objective-C   PHP  Perl  Python  Ruby
# 15976            NaN        4.0  ...         None  None  None    None  None
# 15977            6.0        4.0  ...         None  None  None    None  None
# 15978            6.0        2.0  ...         None   PHP  None    None  None
# 15979            6.0        2.0  ...         None   PHP  Perl  Python  None
# 15980            6.0        4.0  ...         None  None  None    None  None
# 15981            6.0        2.0  ...         None   PHP  Perl  Python  None
# 15982            6.0        2.0  ...         None   PHP  Perl    None  None
# 15983            6.0        4.0  ...         None  None  None    None  None
# 15984            6.0        2.0  ...         None  None  Perl  Python  None
# 15985            6.0        4.0  ...         None  None  None    None  None
# 15986            6.0        2.0  ...         None   PHP  None    None  None
# 15987            6.0        2.0  ...         None  None  None  Python  None
# 15988            6.0        4.0  ...         None  None  None    None  None
# 15989            3.0        4.0  ...         None  None  None    None  None
# 15990            6.0        2.0  ...         None  None  None  Python  None
# 15991            6.0        2.0  ...         None   PHP  None  Python  Ruby
# 15992            6.0        2.0  ...  Objective-C   PHP  Perl  Python  Ruby
# 15993            5.0        4.0  ...         None  None  None    None  None
# 15994            6.0        4.0  ...         None  None  None    None  None
# 15995            4.0        4.0  ...         None  None  None    None  None
# 15996            6.0        4.0  ...         None  None  None    None  None
# 15997            5.0        2.0  ...  Objective-C  None  None    None  None
# 15998            6.0        2.0  ...         None  None  None    None  None
# 15999            5.0        2.0  ...         None  None  None    None  None
#
#         SQL SQL_Server  TypeScript  Year jQuery
# 15700   SQL        NaN        None  2017    NaN
# 15701   SQL        NaN        None  2017    NaN
# 15702  None        NaN        None  2017    NaN
# 15703  None        NaN        None  2017    NaN
# 15704  None        NaN        None  2017    NaN
# 15705  None        NaN        None  2017    NaN
# 15706   SQL        NaN        None  2017    NaN
# 15707  None        NaN        None  2017    NaN
# 15708   SQL        NaN        None  2017    NaN
# 15709   SQL        NaN        None  2017    NaN
# 15710   SQL        NaN        None  2017    NaN
# 15711   SQL        NaN        None  2017    NaN
# 15712   SQL        NaN        None  2017    NaN
# 15713  None        NaN        None  2017    NaN
# 15714   SQL        NaN        None  2017    NaN
# 15715   SQL        NaN        None  2017    NaN
# 15716  None        NaN        None  2017    NaN
# 15717  None        NaN        None  2017    NaN
# 15718  None        NaN        None  2017    NaN
# 15719  None        NaN        None  2017    NaN
# 15720   SQL        NaN        None  2017    NaN
# 15721   SQL        NaN  TypeScript  2017    NaN
# 15722  None        NaN        None  2017    NaN
# 15723   SQL        NaN  TypeScript  2017    NaN
# 15724  None        NaN        None  2017    NaN
# 15725  None        NaN        None  2017    NaN
# 15726  None        NaN        None  2017    NaN
# 15727   SQL        NaN        None  2017    NaN
# 15728   SQL        NaN        None  2017    NaN
# 15729   SQL        NaN        None  2017    NaN
# ...     ...        ...         ...   ...    ...
# 15970   SQL        NaN  TypeScript  2017    NaN
# 15971  None        NaN        None  2017    NaN
# 15972   SQL        NaN        None  2017    NaN
# 15973   SQL        NaN        None  2017    NaN
# 15974   SQL        NaN        None  2017    NaN
# 15975   SQL        NaN  TypeScript  2017    NaN
# 15976  None        NaN        None  2017    NaN
# 15977  None        NaN        None  2017    NaN
# 15978   SQL        NaN  TypeScript  2017    NaN
# 15979   SQL        NaN        None  2017    NaN
# 15980  None        NaN        None  2017    NaN
# 15981   SQL        NaN        None  2017    NaN
# 15982   SQL        NaN        None  2017    NaN
# 15983  None        NaN        None  2017    NaN
# 15984  None        NaN        None  2017    NaN
# 15985  None        NaN        None  2017    NaN
# 15986   SQL        NaN        None  2017    NaN
# 15987   SQL        NaN  TypeScript  2017    NaN
# 15988  None        NaN        None  2017    NaN
# 15989  None        NaN        None  2017    NaN
# 15990   SQL        NaN        None  2017    NaN
# 15991   SQL        NaN        None  2017    NaN
# 15992   SQL        NaN        None  2017    NaN
# 15993  None        NaN        None  2017    NaN
# 15994  None        NaN        None  2017    NaN
# 15995  None        NaN        None  2017    NaN
# 15996  None        NaN        None  2017    NaN
# 15997   SQL        NaN  TypeScript  2017    NaN
# 15998   SQL        NaN  TypeScript  2017    NaN
# 15999   SQL        NaN        None  2017    NaN
#
# [300 rows x 24 columns]

# %%
Total.to_json(r'.\Base_Datos_Encuestas\Total_DBv0json', orient='values')

# %% [markdown]
# A continuación se carga el archivo json unificado a la base de datos en Mongodb

# %% [markdown]
# C:\>mongoimport.exe --db taller_MDB --collection bodega --file C:\Total_DB.json --jsonArray
#
# <img src="./img/load_mongo.PNG">

# %% [markdown]
# Luego se realiza la conexión del cliente mongo con el servidor mongod.
#
# la base de datos se llama taller_MDB y la colección se llama bodega, se cargaron 160.111 documentos:
#
# <img src="./img/load_mongo1.PNG">

# %% [markdown]
# Luego se generan con javascript las funciones map y reduce para responder a la pregunta:  numero de programadores por lenguaje de programación?

# %% [markdown]
# Numero de programadores de AngularJS:  8.842
#
# <img src="./img/Mongo_conteo_AngularJS.PNG">
#
#
# Numero de programadores de C:  18.560
#
#
#
# <img src="./img/Mongo_conteo_C.PNG">
#
#
#
# Numero de programadores de C++: 27.693
#
#
#
# <img src="./img/Mongo_conteo_C++.PNG">
#
#
# Numero de programadores de CSS: 4.364
#
#
#
# <img src="./img/Mongo_conteo_CSS.PNG">
#
#
# Numero de programadores de C#: 43.961
#
#
#
# <img src="./img/Mongo_conteo_C#.PNG">
#
#
# Numero de programadores de HTML5: 2.187
#
#
#
# <img src="./img/Mongo_conteo_HTML5.PNG">
#
#
# Numero de programadores de ObjectiveC: 9.583
#
#
#
# <img src="./img/Mongo_conteo_ObjectiveC.PNG">
#
#
#
# Numero de programadores de PHP: 36.341
#
#
#
# <img src="./img/Mongo_conteo_PHP.PNG">
#
#
# Numero de programadores de Perl: 4.941
#
#
#
# <img src="./img/Mongo_conteo_Perl.PNG">
#
#
# Numero de programadores de Python: 34.430
#
#
#
# <img src="./img/Mongo_conteo_Python.PNG">
#
#
#
# Numero de programadores de Ruby: 11.748
#
#
#
# <img src="./img/Mongo_conteo_Ruby.PNG">
#
#
# Numero de programadores de SQL: 65.467
#
#
#
# <img src="./img/Mongo_conteo_SQL.PNG">
#
#
# Numero de programadores de SQL_Server: 13.435
#
#
# <img src="./img/Mongo_conteo_SQL_Server.PNG">
#
#
# Numero de programadores de TypeScript:  3.565
#
#
#
# <img src="./img/Mongo_conteo_TypeScript.PNG">
#
#
# Numero de programadores de jQuery: 4.193
#
#
#
# <img src="./img/Mongo_conteo_jQuery.PNG">

# %% [markdown]
# ### En resumen, durante los 7 años de encuestas, estos son los programadores por programa

# %% [markdown]
# Numero de programadores de SQL: 65.467
#
# Numero de programadores de C#: 43.961
#
# Numero de programadores de PHP: 36.341
#
# Numero de programadores de Python: 34.430
#
# Numero de programadores de C++: 27.693
#
# Numero de programadores de C:  18.560
#
# Numero de programadores de SQL_Server: 13.435
#
# Numero de programadores de Ruby: 11.748
#
# Numero de programadores de ObjectiveC: 9.583
#
# Numero de programadores de AngularJS:  8.842
#
# Numero de programadores de CSS: 4.364
#
# Numero de programadores de Perl: 4.941
#
# Numero de programadores de jQuery: 4.193
#
# Numero de programadores de TypeScript:  3.565
#
# Numero de programadores de HTML5: 2.187
