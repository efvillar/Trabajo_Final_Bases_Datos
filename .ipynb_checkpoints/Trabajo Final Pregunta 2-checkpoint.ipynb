# %% [markdown]
# # Genere una Bodega de datos que permita responder al menos 15 preguntas elaboradas por el equipo. (Adjunte las 15 preguntas con las 15 consultas SQL que respondan a las preguntas y la respectiva gráfica)

# %% [markdown]
# A partir de la depuración de datos del punto 1, se cargaron las tablas a BigQuery formando así la bodega de datos, a continuación se observan las tablas principales y auxiliares:

# %%
import json
import csv
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
data = pd.read_csv("Total_DB.csv")
data
# Out:
# /home/judarangobu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,6,9,11,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Year                   Country  Gender    Age    Experience Salary  \
# 0       2013                     India     NaN    NaN           NaN    NaN
# 1       2016                    Canada    Male  30-34           NaN    NaN
# 2       2016                    Norway    Male  35-39           NaN    NaN
# 3       2016                  Mongolia    Male  20-24           NaN    NaN
# 4       2016                   Germany    Male  20-24           NaN    NaN
# 5       2016                   Germany     NaN    NaN           NaN    NaN
# 6       2016  United States of America    Male  25-29           NaN    NaN
# 7       2016            United Kingdom    Male  30-34           NaN    NaN
# 8       2016                       NaN    Male  30-34           NaN    NaN
# 9       2016                     China    Male  25-29           NaN    NaN
# 10      2016            United Kingdom    Male  40-50           NaN    NaN
# 11      2015                  Thailand    Male  25-29           NaN    NaN
# 12      2015            United Kingdom    Male  40-50           NaN    NaN
# 13      2016  United States of America    Male  25-29           NaN    NaN
# 14      2016                    Sweden    Male  30-34           NaN    NaN
# 15      2016                   Germany    Male  30-34           NaN    NaN
# 16      2016            United Kingdom    Male   Null           NaN    NaN
# 17      2016                     Spain    Male  35-39           NaN    NaN
# 18      2016                    Poland    Male  30-34           NaN    NaN
# 19      2016                    Poland    Male  20-24           NaN    NaN
# 20      2016                   Austria   Otros  35-39           NaN    NaN
# 21      2016                 Australia    Male  40-50           NaN    NaN
# 22      2016  United States of America    Male  25-29           NaN    NaN
# 23      2016                Kazakhstan    Male  25-29           NaN    NaN
# 24      2013  United States of America     NaN    NaN           NaN    NaN
# 25      2016                    Brazil    Male  25-29           NaN    NaN
# 26      2016                    Poland    Male  25-29           NaN    NaN
# 27      2016                  Portugal    Male  20-24           NaN    NaN
# 28      2016               Netherlands    Male  30-34           NaN    NaN
# 29      2016                   Germany    Male  20-24           NaN    NaN
# ...      ...                       ...     ...    ...           ...    ...
# 160081  2017  United States of America   Otros    NaN     11+ years   Null
# 160082  2017                     India    Male    NaN     11+ years   Null
# 160083  2017  United States of America    Male    NaN     11+ years   Null
# 160084  2017                 Argentina   Otros    NaN  6 - 10 years   Null
# 160085  2017                 Singapore   Otros    NaN     11+ years   Null
# 160086  2017                    Israel    Male    NaN     11+ years   Null
# 160087  2017                 Venezuela    Male    NaN     11+ years   Null
# 160088  2017              South Africa   Otros    NaN     11+ years   Null
# 160089  2017                    Sweden    Male    NaN     11+ years   Null
# 160090  2017                    Turkey   Otros    NaN  6 - 10 years   Null
# 160091  2017                 Australia    Male    NaN     11+ years   Null
# 160092  2017                 Australia   Otros    NaN     11+ years   Null
# 160093  2017                     India    Male    NaN     11+ years   Null
# 160094  2017            United Kingdom   Otros    NaN     11+ years   Null
# 160095  2017                    Russia    Male    NaN     11+ years   Null
# 160096  2017               Philippines   Otros    NaN     11+ years   Null
# 160097  2017               Philippines  Female    NaN     11+ years   Null
# 160098  2017                     Other   Otros    NaN   2 - 5 years   Null
# 160099  2017                   Romania   Otros    NaN     11+ years   Null
# 160100  2017                 Hong Kong   Otros    NaN  6 - 10 years   Null
# 160101  2017                 Argentina    Male    NaN     11+ years   Null
# 160102  2017                 Australia    Male    NaN     11+ years   Null
# 160103  2017                    Sweden    Male    NaN     11+ years   Null
# 160104  2017               Afghanistan   Otros    NaN     11+ years   Null
# 160105  2017                  Barbados    Male    NaN   1 - 2 years   Null
# 160106  2017                      Iran   Otros    NaN  6 - 10 years   Null
# 160107  2017            United Kingdom    Male    NaN     11+ years   Null
# 160108  2017                    Brazil    Male    NaN     11+ years   Null
# 160109  2017               Philippines    Male    NaN     11+ years   Null
# 160110  2017  United States of America   Otros    NaN     11+ years   Null
#
#        AngularJS    C CPlusPlus  CSS  ...   Nodejs   ObjectiveC  PHP  Perl  \
# 0            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 1            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 2            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 3            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 4            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 5            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 6            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 7            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 8            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 9            NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 10           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 11           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 12           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 13           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 14           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 15           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 16           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 17           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 18           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 19           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 20           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 21           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 22           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 23           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 24           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 25           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 26           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 27           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 28           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 29           NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# ...          ...  ...       ...  ...  ...      ...          ...  ...   ...
# 160081       NaN    C       C++  NaN  ...      NaN  Objective-C  PHP   NaN
# 160082       NaN    C       NaN  NaN  ...      NaN          NaN  PHP   NaN
# 160083       NaN  NaN       NaN  NaN  ...      NaN          NaN  PHP   NaN
# 160084       NaN  NaN       NaN  NaN  ...      NaN          NaN  PHP   NaN
# 160085       NaN    C       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160086       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160087       NaN  NaN       NaN  NaN  ...      NaN          NaN  PHP   NaN
# 160088       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160089       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160090       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160091       NaN    C       C++  NaN  ...      NaN  Objective-C  NaN   NaN
# 160092       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160093       NaN  NaN       NaN  NaN  ...      NaN          NaN  PHP   NaN
# 160094       NaN    C       C++  NaN  ...      NaN          NaN  PHP   NaN
# 160095       NaN    C       C++  NaN  ...      NaN          NaN  NaN  Perl
# 160096       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160097       NaN  NaN       NaN  NaN  ...      NaN  Objective-C  NaN   NaN
# 160098       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160099       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160100       NaN  NaN       NaN  NaN  ...      NaN  Objective-C  PHP   NaN
# 160101       NaN    C       NaN  NaN  ...      NaN          NaN  PHP  Perl
# 160102       NaN  NaN       C++  NaN  ...      NaN          NaN  PHP   NaN
# 160103       NaN    C       C++  NaN  ...      NaN          NaN  NaN   NaN
# 160104       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160105       NaN    C       C++  NaN  ...      NaN  Objective-C  PHP   NaN
# 160106       NaN  NaN       NaN  NaN  ...      NaN          NaN  NaN   NaN
# 160096     NaN   NaN  NaN        NaN         NaN    NaN
# 160097     NaN   NaN  SQL        NaN         NaN    NaN
# 160098     NaN   NaN  NaN        NaN         NaN    NaN
# 160099     NaN   NaN  NaN        NaN         NaN    NaN
# 160100     NaN   NaN  SQL        NaN         NaN    NaN
# 160101     NaN   NaN  SQL        NaN         NaN    NaN
# 160102     NaN   NaN  SQL        NaN         NaN    NaN
# 160103  Python   NaN  SQL        NaN         NaN    NaN
# 160104     NaN   NaN  NaN        NaN         NaN    NaN
# 160105     NaN   NaN  SQL        NaN         NaN    NaN
# 160106     NaN   NaN  NaN        NaN         NaN    NaN
# 160107  Python  Ruby  SQL        NaN         NaN    NaN
# 160108     NaN   NaN  SQL        NaN  TypeScript    NaN
# 160109  Python   NaN  SQL        NaN         NaN    NaN
# 160110     NaN   NaN  NaN        NaN         NaN    NaN
#
# [160111 rows x 24 columns]

# %% [markdown]
# ## PREGUNTAS

# %% [markdown]
# ### 1.  Cuales son los 5 lenguajes de programación más usados en el año 2017 y 2011?

# %%
dataset1 = data[['Year','AngularJS','C', 'CPlusPlus','CSS','CSharp','HTML5','Java','JavaScript','Nodejs','ObjectiveC','PHP','Perl','Python','Ruby','SQL','SQL_Server','TypeScript','jQuery']]

data2017 = dataset1[dataset1["Year"] == 2017].count().sort_values(ascending = False).reset_index()
datos2017 =data2017.drop([0],axis=0).head(5).plot.bar(x = "index", y = 0)

data2011 = dataset1[dataset1["Year"] == 2011].count().sort_values(ascending = False).reset_index()
datos2011 =data2011.drop([0],axis=0).head(5).plot.bar(x = "index", y = 0)

# %% [markdown]
# ### 2. Cuáles fueron los 8 países con más preguntas durante el año 2013?

# %%
datos= data.loc[:, ['Year', 'Country']]
Paises2013 = datos[datos["Year"] == 2013].groupby(['Country']).count()
Paises = Paises2013.sort_values('Year',ascending=False).head(8)
Paises.plot.bar()

# %%
Paises.plot(kind='barh', alpha = 0.8, color='br',figsize=(20,10))
plt.title('8 países más realizaron preguntas durante el año 2013',fontsize=20)
plt.ylabel("Países", fontsize=20)
# Out:
# Text(0,0.5,'Países')

# %% [markdown]
# ### 4. Cuántas fueron las preguntas realizadas en Estados Unidos por año?

# %%
datos= data.loc[:, ['Year', 'Country']]
Paises2013 = datos[datos["Country"] == 'United States of America'].groupby(['Year']).count()
Paises2013
# Out:
#       Country
# Year
# 2011     1037
# 2012     1785
# 2013     3181
# 2014     2128
# 2015     4745
# 2016    13539
# 2017    11508

# %%
plt.figure(figsize=(13,8))
plt.plot(Paises2013, '-o', ms=20, lw=1, alpha=0.7, mfc='orange',linewidth=3)
plt.title("Número de preguntas realizadas por ciudadanos estadounidenses por año", fontsize=18)  # Establece el título del gráfico
plt.ylabel("Número de preguntas", fontsize=15)   # Establece el título del eje y
# Out:
# /home/judarangobu/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:2446: UserWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'
#   seen=seen, canon=canonical, used=seen[-1]))
# Text(0,0.5,'Número de preguntas')

# %% [markdown]
# ### 5. Cuántas personas por género presentan salarios entre 140.001-160.000,160.001-180.000 y 180.001-200.000?

# %%
Salario =pd.crosstab(data.Salary, data.Gender).reset_index().loc[[3,4,5]]
Salario
# Out:
# Gender             Salary  Female  Male  Otros
# 3       $140.001-$160.000      66  1761     48
# 4       $160.001-$180.000      28  1017     46
# 5       $180.001-$200.000      30   889     40

# %%
Salario.plot(kind='bar', alpha = 0.8,figsize=(20,10))
plt.title('8 países más realizaron preguntas durante el año 2013',fontsize=20)
plt.ylabel("Países", fontsize=20)
# Out:
# Text(0,0.5,'Países')

# %% [markdown]
# ### 6. Cuál es el lenguaje de programación más usado por genero?

# %%
data2014 = dataset1[dataset1["Year"] == 2014].count().sort_values(ascending = False)
data2014

#data[data['Year']==data2014[1]]
# Out:
# Year          7643
# JavaScript    3783
# SQL           3467
# Java          2479
# CSharp        2378
# PHP           1710
# Python        1473
# CPlusPlus     1418
# C             1174
# ObjectiveC     675
# Nodejs         641
# Ruby           593
# Perl            91
# CSS             42
# jQuery          21
# AngularJS       12
# HTML5            8
# TypeScript       4
# SQL_Server       0
# dtype: int64

# %%
pd.crosstab(data.Salary, data.SQL).reset_index()
# Out:
# SQL                Salary  Current Lang & Tech: SQL    SQL
# 0              $0-$20.000                         0  10130
# 1       $100.001-$120.000                         0   3412
# 2       $120.001-$140.000                         0   1735
# 3       $140.001-$160.000                         0   1280
# 4       $160.001-$180.000                         0    492
# 5       $180.001-$200.000                         0    439
# 6         $20.001-$40.000                         0   7590
# 7         $40.001-$60.000                         0   7655
# 8         $60.001-$80.000                         0   6555
# 9        $80.001-$100.000                         0   4454
# 10                   Null                         0  12280
# 11                   Otro                         1     96
# 12         Rather not say                         0   3854
# 13   Student / Unemployed                         0   1960

# %%
data2014.pivot_table()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-ea7e4088b8dd> in <module>()
# ----> 1 data2014.pivot_table()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pivot_table'

# %% [markdown]
# ### 5. Cuál es el lenguaje de programación más usado por rango de experiencia en 2017?
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 6. Cual lenguaje de programación tuvo mayor crecimiento en los ultimos 3 años?
#
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 7. Cual lenguaje de programación tuvo mayor decrecimiento en los ultimos 3 años?
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 8. Cuál es el lenguaje de programación más usado por rango de edad en 2017?
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 9. En el rango de salarios más alto, cual es la proporción por género?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 10. En Colombia, cual es el lenguaje de programación más usado por año?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 11.  En Estados Unidos, cual es el lenguaje de programación más usado por año?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 12.  Qué pais tiene mayor proporción de programadores con mayor experiencia?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 13.  En los principales paises de Europa, cual es el lenguaje de programación más usado?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 14.  Cuales lenguajes de programación usados en 2017 no se usaban en 2011?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica

# %% [markdown]
# ### 15. Cual es el lenguaje de programación con menores salarios?
#
# #### Consulta en SQL
#
#
#
#
#
#
# #### Respuesta
#
#
#
#
#
#
# #### Gráfica
